# %%
library(tidyverse)
library(plotly)

# set options for displaying data frames
options(tibble.print_max = Inf, repr.matrix.max.rows = Inf)

# %%
# load data
data <- read.csv("https://data.london.gov.uk/download/london-underground-average-monthly-temperatures/b01c7853-fff2-4781-9755-9b5e1404d78c/lu-average-monthly-temperatures.csv")

# # create a histogram using ggplot2
# ggplot(data, aes(x = date)) + 
#   geom_histogram(binwidth = 1, color = "black", fill = "white") + 
#   labs(title = "Histogram of Date Variable", x = "Date", y = "Count")
data
# Out:
#    Year Month     Bakerloo Central Jubilee Northern Piccadilly Victoria
# 1  2013 January   21.70    21.00   16.40   19.50    19.30      18.40
# 2  2013 February  21.50    21.00   17.90   19.80    19.00      18.30
# 3  2013 March     21.70    20.90   18.20   20.00    18.70      17.70
# 4  2013 April     23.40    22.80   20.30   21.40    20.30      19.60
# 5  2013 May       25.40    24.70   21.90   22.90    22.40      21.50
# 6  2013 June      27.00    26.70   23.10   23.70    24.20      23.30
# 7  2013 July      29.70    30.00   26.30   25.90    27.50      26.50
# 8  2013 August    29.90    30.00   26.10   26.20    27.40      26.60
# 9  2013 September 28.90    28.20   24.50   25.10    26.10      25.10
# 10 2013 October   27.90    27.10   23.10   24.20    25.10      24.10
# 11 2013 November  25.40    24.50   20.10   22.10    22.40      21.50
# 12 2013 December  23.90    23.10   19.70   21.20    21.00      20.00
# 13 2014 January   23.40    22.70   19.60   20.70    20.60      19.60
# ...

# %%
df_byyears <- df %>%
# gather(key = "Line", value = "Temperature", -Year) %>%
mutate(Line = factor(Line, levels = c("Bakerloo", "Central", "Jubilee", "Northern", "Piccadilly", "Victoria", "Waterloo_and_City", "Subsurface_lines"))) %>%
group_by(Year, Line) %>%
summarize(Temperature = mean(Temperature))
# Out:
# Error in UseMethod("mutate"): no applicable method for 'mutate' applied to an object of class "function"
# Traceback:
#
# 1. df %>% mutate(Line = factor(Line, levels = c("Bakerloo", "Central",
#  .     "Jubilee", "Northern", "Piccadilly", "Victoria", "Waterloo_and_City",
#  .     "Subsurface_lines"))) %>% group_by(Year, Line) %>% summarize(Temperature = mean(Temperature))
# 2. summarize(., Temperature = mean(Temperature))
# 3. group_by(., Year, Line)
# 4. mutate(., Line = factor(Line, levels = c("Bakerloo", "Central",
#  .     "Jubilee", "Northern", "Piccadilly", "Victoria", "Waterloo_and_City",
#  .     "Subsurface_lines")))
